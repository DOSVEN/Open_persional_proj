# %%
import os 
import shutil
import glob
from tqdm import tqdm

# %% [markdown]
# [Nguồn tải Data: mrlEyes_2018_01](http://mrl.cs.vsb.cz/eyedataset)

# %% [markdown]
# subject ID:
# xxx
#
# image number:
# xxx
#
# gender:
# 0 - male
# 1 - famale
#
# glasses:
# 0 - no
# 1 - yes
#
# eye state:
# 0 - close
# 1 - open
#
# reflections:
# 0 - none
# 1 - low
# 2 - high
#
# lighting conditions/image quality:
# 0 - bad
# 1 - good
#
# sensor type:
# 01 - RealSense SR300 640x480
# 02 - IDS Imaging, 1280x1024
# 03 - Aptina Imagin 752x480
#
# example:
# s001_00123_0_0_0_0_0_01.png

# %%
Raw_DIR= r'/Users/dosven/jupyter_note/Personal_Proj/ngugatlaixe/mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst=r'/Users/dosven/jupyter_note/Personal_Proj/ngugatlaixe/Prepared_Data/Close Eyes')
        
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst=r'/Users/dosven/jupyter_note/Personal_Proj/ngugatlaixe/Prepared_Data/Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|██████████████████████████████████████| 1889/1889 [00:02<00:00, 857.34it/s]
